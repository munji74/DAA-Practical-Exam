# %%
import time
import matplotlib.pyplot as plt


def insertion_sort(lst1):
    for i in range(1, len(lst1)):
        key = lst1[i]
        j = i - 1
        while j >= 0 and key < lst1[j]:
            lst1[j + 1] = lst1[j]
            j -= 1
        lst1[j + 1] = key

lst1 = [3, 2, 5, 4, 8]  #n = 5
#lst1 = [3, 2, 5, 4, 8, 6, 10, 9, 7, 1]   #n = 10
#lst1 = [13, 2, 15, 4, 8, 6, 1, 9, 7, 5, 11, 10, 12, 14, 3]  #n = 15
#lst1 = [13, 2, 15, 4, 8, 6, 1, 9, 7, 5, 11, 10, 12, 14, 3, 21, 24, 20 ,19 ,18 ]  #n = 20

input_size = [5, 10, 15, 20]
timetaken = [0.4053, 1.0729, 1.3113, 1.5972]


start = time.time()
insertion_sort(lst1)
end = time.time()

print(f"The sorted array: {lst1}")
print(f"It took {end - start:.10f} seconds for insertion sort")


plt.plot(input_size, timetaken, label='Insertion Sort')
plt.xlabel('Input Size')
plt.ylabel('Time (seconds)')
plt.title('Insertion Sort Performance')
plt.legend()
plt.show()
# Out:
# The sorted array: [2, 3, 4, 5, 8]
# It took 0.0000939369 seconds for insertion sort

# %%
import time
import matplotlib.pyplot as plt


def selection_sort(lst1):
    for i in range(len(lst1)):
        min_index = i
        for j in range(i + 1, len(lst1)):
            if lst1[j] < lst1[min_index]:
                min_index = j
        lst1[i], lst1[min_index] = lst1[min_index], lst1[i]


lst1 = [3, 2, 5, 4, 8]  #n = 5
#lst1 = [3, 2, 5, 4, 8, 6, 10, 9, 7, 1]   #n = 10
#lst1 = [13, 2, 15, 4, 8, 6, 1, 9, 7, 5, 11, 10, 12, 14, 3]  #n = 15
#lst1 = [13, 2, 15, 4, 8, 6, 1, 9, 7, 5, 11, 10, 12, 14, 3, 21, 24, 20 ,19 ,18 ]  #n = 20


input_size = [5, 10, 15, 20]
timetaken = [0.90599, 1.3828, 1.5974, 2.0505]

start = time.time()
selection_sort(lst1)
end = time.time()

print(f"The sorted array: {lst1}")
print(f"It took {end - start:.10f} seconds for selection sort")


plt.plot(input_size, timetaken, label='Insertion Sort')
plt.xlabel('Input Size')
plt.ylabel('Time (seconds)')
plt.title('Selection Sort Performance')
plt.legend()
plt.show()
# Out:
# The sorted array: [2, 3, 4, 5, 8]
# It took 0.0001101494 seconds for selection sort

# %% [markdown]
# CONCLUSIONS FROM BOTH THE GRAPHS
# Both Algorithms are inefficient since they run at worst case quadratic run time but Insertion sort seems to decrease in performance worse than selection sort with the same number of input
